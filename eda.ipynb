# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv(r"D:\DAILY TASKS\housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.drop('longitude',axis=1)
# Out:
#        latitude  housing_median_age  total_rooms  total_bedrooms  population  \
# 0         37.88                41.0        880.0           129.0       322.0
# 1         37.86                21.0       7099.0          1106.0      2401.0
# 2         37.85                52.0       1467.0           190.0       496.0
# 3         37.85                52.0       1274.0           235.0       558.0
# 4         37.85                52.0       1627.0           280.0       565.0
# ...         ...                 ...          ...             ...         ...
# 20635     39.48                25.0       1665.0           374.0       845.0
# 20636     39.49                18.0        697.0           150.0       356.0
# 20637     39.43                17.0       2254.0           485.0      1007.0
# 20638     39.43                18.0       1860.0           409.0       741.0
# 20639     39.37                16.0       2785.0           616.0      1387.0
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.dropna(inplace=True)

# %%
df.fillna(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df["total_rooms"].map(lambda x:x+500)
# Out:
# 0        1380.0
# 1        7599.0
# 2        1967.0
# 3        1774.0
# 4        2127.0
#           ...
# 20635    2165.0
# 20636    1197.0
# 20637    2754.0
# 20638    2360.0
# 20639    3285.0
# Name: total_rooms, Length: 20433, dtype: float64

# %%
df["ocean_proximity"].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
df.rename(columns={"longitude":"L"},inplace=True)
df
# Out:
#             L  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# ...       ...       ...                 ...          ...             ...
# 20635 -121.09     39.48                25.0       1665.0           374.0
# 20636 -121.21     39.49                18.0        697.0           150.0
# 20637 -121.22     39.43                17.0       2254.0           485.0
# 20638 -121.32     39.43                18.0       1860.0           409.0
# 20639 -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values Heatmap")
plt.show()

# %%
categorical_cols = df.select_dtypes(include=['string']).columns
print("Categorical columns:", categorical_cols)
# Out:
# Categorical columns: Index([], dtype='object')

# %%
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
df
# Out:
#             L  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -122.25     37.85                52.0       1274.0           235.0
# 4     -122.25     37.85                52.0       1627.0           280.0
# ...       ...       ...                 ...          ...             ...
# 20635 -121.09     39.48                25.0       1665.0           374.0
# 20636 -121.21     39.49                18.0        697.0           150.0
# 20637 -121.22     39.43                17.0       2254.0           485.0
# 20638 -121.32     39.43                18.0       1860.0           409.0
# 20639 -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# ...

# %%
numerical_cols = df.select_dtypes(include=['int64','float64']).columns
print("numerical_cols:",numerical_cols)
# Out:
# numerical_cols: Index(['L', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms',
#        'population', 'households', 'median_income', 'median_house_value'],
#       dtype='object')

# %%
df[numerical_cols].hist(bins=30, figsize=(15,10))
plt.suptitle("Numerical Features Distribution")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
df
# Out:
#               L  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -1.327314  1.051717            0.982163    -0.803813       -0.970325
# 1     -1.322323  1.042355           -0.606210     2.042130        1.348276
# 2     -1.332305  1.037674            1.855769    -0.535189       -0.825561
# 3     -1.337296  1.037674            1.855769    -0.623510       -0.718768
# 4     -1.337296  1.037674            1.855769    -0.461970       -0.611974
# ...         ...       ...                 ...          ...             ...
# 20635 -0.758318  1.800677           -0.288535    -0.444580       -0.388895
# 20636 -0.818212  1.805358           -0.844466    -0.887557       -0.920488
# 20637 -0.823203  1.777272           -0.923885    -0.175042       -0.125472
# 20638 -0.873115  1.777272           -0.844466    -0.355344       -0.305834
# 20639 -0.833186  1.749186           -1.003304     0.067955        0.185416
#
#        population  households  median_income  median_house_value  \
# ...

# %%
fig, axs = plt.subplots (1,4, figsize = (16,6))
axs[0].boxplot(df.latitude)
axs[1].boxplot(df. housing_median_age)
axs [2].boxplot(df. median_income)
axs [3].boxplot(df.median_house_value)
plt.show()

# %%
sns.pairplot(df)

# %%
plt.show()
plt.plot(df.population,color="green")
plt.grid()
plt.xlabel("households")
plt.ylabel("population")
# Out:
# Text(0, 0.5, 'population')

# %%
se=df[["housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"]]
se.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0            0.982163    -0.803813       -0.970325   -0.973320   -0.976833
# 1           -0.606210     2.042130        1.348276    0.861339    1.670373
# 2            1.855769    -0.535189       -0.825561   -0.819769   -0.843427
# 3            1.855769    -0.623510       -0.718768   -0.765056   -0.733562
# 4            1.855769    -0.461970       -0.611974   -0.758879   -0.628930
#
#    median_income  median_house_value
# 0       2.345163            2.128819
# 1       2.332632            1.313626
# 2       1.782939            1.258183
# 3       0.932970            1.164622
# 4      -0.013143            1.172418

# %%
x=df[["housing_median_age","total_rooms","total_bedrooms","population","households","median_income"]]
y=df[["median_house_value"]]

# %%
x.shape, y.shape
# Out:
# ((20433, 6), (20433, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train.shape, y_test.shape, x_test.shape, y_train.shape
# Out:
# ((16346, 6), (4087, 1), (4087, 6), (16346, 1))

# %%
scaler =StandardScaler()
df["housing_median_age"] = scaler.fit_transform(df[["housing_median_age"]])
df["total_roons"] = scaler.fit_transform(df[["total_rooms"]])
df["total_bedrooms"] = scaler.fit_transform(df[["total_bedrooms"]])
df["population"] = scaler.fit_transform(df[["population"]])
df["households"] = scaler.fit_transform(df[["households"]])
df
# Out:
#               L  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -1.327314  1.051717            0.982163    -0.803813       -0.970325
# 1     -1.322323  1.042355           -0.606210     2.042130        1.348276
# 2     -1.332305  1.037674            1.855769    -0.535189       -0.825561
# 3     -1.337296  1.037674            1.855769    -0.623510       -0.718768
# 4     -1.337296  1.037674            1.855769    -0.461970       -0.611974
# ...         ...       ...                 ...          ...             ...
# 20635 -0.758318  1.800677           -0.288535    -0.444580       -0.388895
# 20636 -0.818212  1.805358           -0.844466    -0.887557       -0.920488
# 20637 -0.823203  1.777272           -0.923885    -0.175042       -0.125472
# 20638 -0.873115  1.777272           -0.844466    -0.355344       -0.305834
# 20639 -0.833186  1.749186           -1.003304     0.067955        0.185416
#
#        population  households  median_income  median_house_value  \
# ...

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error, r2_score

# %%
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_ , model.coef_
# Out:
# (array([-0.00096502]),
#  array([[ 0.20517043, -0.37645305,  0.38321875, -0.33009932,  0.3852114 ,
#           0.78480275]]))

# %%
p_val= model.predict(x_test)
p_val
# Out:
# array([[-0.3585131 ],
#        [-0.39651356],
#        [-0.08672007],
#        ...,
#        [-0.75736247],
#        [-0.24418932],
#        [-0.55592375]], shape=(4087, 1))

# %%
mean_squared_error(y_test,p_val)#near to 0
# Out:
# 0.44020514982377856

# %%
r2_score(y_test,p_val)#near to 1
# Out:
# 0.5710755317440979
